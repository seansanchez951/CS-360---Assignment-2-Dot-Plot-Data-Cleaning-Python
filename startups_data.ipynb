# %%
import pandas as pd
import numpy as np
import re

# %%
# display all rows in columns
pd.options.display.max_columns = None
pd.options.display.max_rows = None

# %%
dataframe = pd.read_csv(r'C:\Users\seans\Documents\School\CS 360 - Data Visualization\Startups.csv')

# %%
dataframe
# Out:
#                         Company  Valuation Valuation_date  \
# 0                     ByteDance     140.00       April-21
# 1                        SpaceX     100.00     October-21
# 2                        Stripe      95.00       March-21
# 3                        Klarna      45.60        June-21
# 4                         Canva      40.00   September-21
# 5                     Instacart      39.00       March-21
# 6                    Databricks      38.00      August-21
# 7                       Revolut      33.00        July-21
# 8                        Nubank      30.00        June-21
# 9                      Telegram      30.00     January-21
# 10                   Epic Games      28.70       April-21
# 11                        Chime      25.00      August-21
# 12                          FTX      25.00     October-21
# 13                       Byju's      21.00    November-21
# 14                  Xiaohongshu      20.00     October-21
# ...

# %%
dataframe.dtypes
# Out:
# Company            object
# Valuation         float64
# Valuation_date     object
# Industry           object
# Country            object
# dtype: object

# %%
df = dataframe.copy()

# %%
df['Country'] = df['Country'].astype(str)

# %%
df.dtypes
# Out:
# Company            object
# Valuation         float64
# Valuation_date     object
# Industry           object
# Country            object
# dtype: object

# %%
df
# Out:
#                         Company  Valuation Valuation_date  \
# 0                     ByteDance     140.00       April-21
# 1                        SpaceX     100.00     October-21
# 2                        Stripe      95.00       March-21
# 3                        Klarna      45.60        June-21
# 4                         Canva      40.00   September-21
# 5                     Instacart      39.00       March-21
# 6                    Databricks      38.00      August-21
# 7                       Revolut      33.00        July-21
# 8                        Nubank      30.00        June-21
# 9                      Telegram      30.00     January-21
# 10                   Epic Games      28.70       April-21
# 11                        Chime      25.00      August-21
# 12                          FTX      25.00     October-21
# 13                       Byju's      21.00    November-21
# 14                  Xiaohongshu      20.00     October-21
# ...

# %%
# make dataset for top 10 companies overall
df_top10 = df.iloc[0:10]

# %%
df_top10
# Out:
#       Company  Valuation Valuation_date            Industry  \
# 0   ByteDance      140.0       April-21            Internet
# 1      SpaceX      100.0     October-21           Aerospace
# 2      Stripe       95.0       March-21  Financial services
# 3      Klarna       45.6        June-21             Fintech
# 4       Canva       40.0   September-21      Graphic design
# 5   Instacart       39.0       March-21              Retail
# 6  Databricks       38.0      August-21            Software
# 7     Revolut       33.0        July-21             Fintech
# 8      Nubank       30.0        June-21  Financial services
# 9    Telegram       30.0     January-21            Internet
#
#                      Country
# 0                      China
# 1              United States
# 2   United States /  Ireland
# 3                     Sweden
# 4                  Australia
# 5              United States
# 6              United States
# 7             United Kingdom
# 8                     Brazil
# ...

# %%
# make df of top 10 companies by valuation
df_top10final = df_top10[['Company','Valuation']]

# %%
# write csv file for top 10 startups overall
df_top10final.to_csv('Top 10 Startups Overall.csv', header=True, index=False)

# %%
df['Country'].iloc[1]
# Out:
# '\xa0United States'

# %%
# reduce dataframe to only companies based in United States
is_us = df['Country']=="\xa0United States"

# %%
print(is_us)
# Out:
# 0      False
# 1       True
# 2      False
# 3      False
# 4      False
# 5       True
# 6       True
# 7      False
# 8      False
# 9      False
# 10      True
# 11      True
# 12     False
# 13     False
# 14     False
# 15      True
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21      True
# 22     False
# 23      True
# 24      True
# 25      True
# 26      True
# 27      True
# 28     False
# 29      True
# 30     False
# 31     False
# 32     False
# 33     False
# 34      True
# 35     False
# 36      True
# 37      True
# 38      True
# 39     False
# 40      True
# 41      True
# 42      True
# 43     False
# 44     False
# 45      True
# 46     False
# 47      True
# 48      True
# 49     False
# 50     False
# 51      True
# 52     False
# 53      True
# 54      True
# 55     False
# 56     False
# 57     False
# 58     False
# 59     False
# 60      True
# 61     False
# 62      True
# 63     False
# 64     False
# 65      True
# ...

# %%
df_us = df[is_us]

# %%
df_us = df_us.reset_index()

# %%
df_us
# Out:
#     index                 Company  Valuation Valuation_date  \
# 0       1                  SpaceX     100.00     October-21
# 1       5               Instacart      39.00       March-21
# 2       6              Databricks      38.00      August-21
# 3      10              Epic Games      28.70       April-21
# 4      11                   Chime      25.00      August-21
# 5      15                Fanatics      18.00      August-21
# 6      21                  GoPuff      15.00        July-21
# 7      23                   Plaid      13.40       April-21
# 8      24               Grammarly      13.00    November-21
# 9      25                   Faire      12.40    November-21
# 10     26                    Brex      12.30     October-21
# 11     27  Biosplice Therapeutics      12.00       April-21
# 12     29                GoodLeap      12.00     October-21
# 13     34                  Aurora      10.00    December-20
# 14     36  Digital Currency Group      10.00    November-21
# ...

# %%
df_us.columns
# Out:
# Index(['index', 'Company', 'Valuation', 'Valuation_date', 'Industry',
#        'Country'],
#       dtype='object')

# %%
df_us.dtypes
# Out:
# index               int64
# Company            object
# Valuation         float64
# Valuation_date     object
# Industry           object
# Country            object
# dtype: object

# %%
df_us = df_us.drop(columns=('index'))

# %%
df_us
# Out:
#                    Company  Valuation Valuation_date  \
# 0                   SpaceX     100.00     October-21
# 1                Instacart      39.00       March-21
# 2               Databricks      38.00      August-21
# 3               Epic Games      28.70       April-21
# 4                    Chime      25.00      August-21
# 5                 Fanatics      18.00      August-21
# 6                   GoPuff      15.00        July-21
# 7                    Plaid      13.40       April-21
# 8                Grammarly      13.00    November-21
# 9                    Faire      12.40    November-21
# 10                    Brex      12.30     October-21
# 11  Biosplice Therapeutics      12.00       April-21
# 12                GoodLeap      12.00     October-21
# 13                  Aurora      10.00    December-20
# 14  Digital Currency Group      10.00    November-21
# 15                   Figma      10.00        June-21
# 16                   Gusto      10.00      August-21
# ...

# %%
df_us['Industry'] = df_us['Industry'].astype(str)

# %%
is_soft = df_us['Industry']=="Software"

# %%
is_soft
# Out:
# 0     False
# 1     False
# 2      True
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8      True
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15     True
# 16     True
# 17     True
# 18    False
# 19    False
# 20    False
# 21     True
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27     True
# 28    False
# 29    False
# 30    False
# 31    False
# 32     True
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# 48    False
# 49    False
# 50    False
# 51    False
# 52    False
# 53    False
# 54    False
# 55    False
# 56    False
# 57    False
# 58    False
# 59    False
# 60    False
# 61    False
# 62    False
# 63    False
# 64    False
# 65     True
# 66    False
# 67    False
# 68    False
# 69    False
# 70    False
# ...

# %%
df_ussoft = df_us[is_soft]

# %%
df_ussoft
# Out:
#            Company  Valuation Valuation_date  Industry         Country
# 2       Databricks       38.0      August-21  Software   United States
# 8        Grammarly       13.0    November-21  Software   United States
# 15           Figma       10.0        June-21  Software   United States
# 16           Gusto       10.0      August-21  Software   United States
# 17     Notion Labs       10.0     October-21  Software   United States
# 21    ServiceTitan        9.5        June-21  Software   United States
# 27           Carta        7.4      August-21  Software   United States
# 32         Discord        7.0    December-20  Software   United States
# 65        Cohesity        3.7       March-21  Software   United States
# 83        Calendly        3.0     January-21  Software   United States
# 84    Grafana Labs        3.0      August-21  Software   United States
# 86  Lucid Software        3.0        June-21  Software   United States

# %%
df_ussoft = df_ussoft.reset_index()

# %%
df_ussoft = df_ussoft.drop(columns=('index'))

# %%
df_ussoft
# Out:
#            Company  Valuation Valuation_date  Industry         Country
# 0       Databricks       38.0      August-21  Software   United States
# 1        Grammarly       13.0    November-21  Software   United States
# 2            Figma       10.0        June-21  Software   United States
# 3            Gusto       10.0      August-21  Software   United States
# 4      Notion Labs       10.0     October-21  Software   United States
# 5     ServiceTitan        9.5        June-21  Software   United States
# 6            Carta        7.4      August-21  Software   United States
# 7          Discord        7.0    December-20  Software   United States
# 8         Cohesity        3.7       March-21  Software   United States
# 9         Calendly        3.0     January-21  Software   United States
# 10    Grafana Labs        3.0      August-21  Software   United States
# 11  Lucid Software        3.0        June-21  Software   United States

# %%
df_clean = df_ussoft[['Company','Valuation']]

# %%
df_clean
# Out:
#            Company  Valuation
# 0       Databricks       38.0
# 1        Grammarly       13.0
# 2            Figma       10.0
# 3            Gusto       10.0
# 4      Notion Labs       10.0
# 5     ServiceTitan        9.5
# 6            Carta        7.4
# 7          Discord        7.0
# 8         Cohesity        3.7
# 9         Calendly        3.0
# 10    Grafana Labs        3.0
# 11  Lucid Software        3.0

# %%
# write processsed df to csv file
df_clean.to_csv('US Software Startups.csv', header=True, index=False)
